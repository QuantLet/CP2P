# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import plot, show, grid, xlabel, ylabel

# %%
pd.options.mode.chained_assignment = None  # default='warn'
eth = pd.read_csv("data/20211212_ETH-USD_y.csv")

eth.loc[eth['Date']=='2021-05-01']
# Out:
#            Date         Open         High          Low        Close  \
# 140  2021-05-01  2772.838379  2951.440918  2755.908447  2945.892822
#
#        Adj Close       Volume
# 140  2945.892822  28726205272

# %%
plt.plot(eth['Date'], eth['Close'])
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(90))
#plt.title('ETH values over one year')
plt.savefig('plots/year_ETH.png', transparent=True)
show()

# %%
# subset: may and june
eth_may = eth[140:200]
eth_may.index = range(0,len(eth_may))
eth_may.index.name = 't'
eth_may['LTV']=''
eth_may['H']=''
eth_may['Coins']=''
eth_may['Collateral']=''
eth_may['Debt']=''
eth_may['Liquidations']=''

# %%
'''
example contract
'''

LTVH  = 0.85                  # liquidation threshold LTV
gamma = 0.1                   # contract interest payment

q0   = 6000                   # initial debt

N0   = 3                      # initial number of coins

S0   = eth_may['Close'][0]
C0   = N0*S0                  # collateral
BC0  = LTVH*C0                # borrowing capacity
H0   = q0/(LTVH*N0)           # initial liquidation threshold in unit of price
print('BC =', BC0, '\nH0 =', H0, '\nS(0) =', S0, '\nC(0) =', C0)

LTV0 = q0/C0                  # initial LTV
print('Borrower obtains a loan q =', q0, 'with an initial LTV ratio of LTV =',LTV0)
# Out:
# BC = 7512.026696099999
# H0 = 2352.9411764705883
# S(0) = 2945.892822
# C(0) = 8837.678466
# Borrower obtains a loan q = 6000 with an initial LTV ratio of LTV = 0.6789113253082227

# %%
'''
coin liquidation function
'''
def Ni(N0, LTV):
    N = N0*(1-(LTV/(2*LB)))
    
    if LTV > 2*LB:
        N = 0
    if N <= 0.001:
        N = 0
    
    return N

# %%
'''
construction of contract over time in two datasets
Assumption: borrower never takes action to avoid liquidation

dataset liqu contains information only about liquidation events; eth_may is whole development over time
'''

eth_may['Collateral'][0] = C0
eth_may['LTV'][0]        = LTV0
eth_may['Coins'][0]      = N0
eth_may['Debt'][0]       = q0
eth_may['H'][0]          = H0

eth_may['Liquidations'][0] = 0

L  = 0           # number of liquidations
LB = 0.95        # liquidation penalty

liqu = eth_may.iloc[0:1]
for i in range(1,len(eth_may)): 
    if eth_may['LTV'][i-1] >= LTVH:
        cont = 1
        L   += 1
        
        liqu.loc[r'$\tau_{}^-$'.format(L)] = eth_may.iloc[i-1]
        liqu.loc[r'$\tau_{}^+$'.format(L)] = eth_may.iloc[i-1]
        
        eth_may['Debt'][i]  = np.exp(gamma*(1/365.25))*eth_may['Debt'][i-1]/2
        
        while cont > 0:                
            liqu['Debt'][r'$\tau_{}^+$'.format(L)]  = liqu['Debt'][r'$\tau_{}^-$'.format(L)]/2
            liqu['Coins'][r'$\tau_{}^+$'.format(L)] = Ni(liqu['Coins'][r'$\tau_{}^-$'.format(L)], eth_may['LTV'][i-1])
            
            # set all parameters to zero if all coins are liquidated
            if liqu['Coins'][r'$\tau_{}^+$'.format(L)] == 0:
                liqu['Collateral'][r'$\tau_{}^+$'.format(L)] = 0
                liqu['LTV'][r'$\tau_{}^+$'.format(L)]        = 0
                liqu['H'][r'$\tau_{}^+$'.format(L)]          = 0
                liqu['Debt'][r'$\tau_{}^+$'.format(L)]       = 0
 
            else: 
                liqu['Collateral'][r'$\tau_{}^+$'.format(L)]   = liqu['Coins'][r'$\tau_{}^+$'.format(L)]*liqu['Close'][r'$\tau_{}^+$'.format(L)]
                liqu['LTV'][r'$\tau_{}^+$'.format(L)]          = liqu['Debt'][r'$\tau_{}^+$'.format(L)]/(liqu['Collateral'][r'$\tau_{}^+$'.format(L)])
                liqu['H'][r'$\tau_{}^+$'.format(L)]            = liqu['Debt'][r'$\tau_{}^+$'.format(L)]/(liqu['Coins'][r'$\tau_{}^+$'.format(L)]*LTVH)
    
            eth_may['Liquidations'][i] = L 
            liqu['Liquidations'][r'$\tau_{}^+$'.format(L)] = L
            
            # continue if LTV is still too high
            if liqu['LTV'][r'$\tau_{}^+$'.format(L)] >= LTVH:
                cont += 1
                L    += 1
                liqu.loc[r'$\tau_{}^-$'.format(L)] = liqu.loc[r'$\tau_{}^+$'.format(L-1)]
                liqu.loc[r'$\tau_{}^+$'.format(L)] = liqu.loc[r'$\tau_{}^+$'.format(L-1)]
                continue
            else:
                cont = 0
                
        eth_may['Coins'][i] = liqu['Coins'][r'$\tau_{}^+$'.format(L)]
        eth_may['Debt'][i]  = liqu['Debt'][r'$\tau_{}^+$'.format(L)]
        if eth_may['Coins'][i] == 0:
            eth_may['Collateral'][i] = 0
            eth_may['LTV'][i]  = 0
            eth_may['H'][i]    = 0
            eth_may['Debt'][i] = 0
        
        else:
            eth_may['Collateral'][i]   = eth_may['Coins'][i]*eth_may['Close'][i]
            eth_may['LTV'][i]          = eth_may['Debt'][i]/eth_may['Collateral'][i]   
            eth_may['H'][i]            = eth_may['Debt'][i]/(eth_may['Coins'][i]*LTVH) 
        
    else:
        eth_may['Debt'][i]  = np.exp(gamma*(1/365.25))*eth_may['Debt'][i-1]
        eth_may['Coins'][i] = eth_may['Coins'][i-1]
        
        eth_may['Collateral'][i] = eth_may['Coins'][i]*eth_may['Close'][i]
        eth_may['LTV'][i]   = eth_may['Debt'][i]/eth_may['Collateral'][i]
        
        eth_may['H'][i]     = eth_may['Debt'][i]/(eth_may['Coins'][i]*LTVH)
        
    if eth_may['Coins'][i-1] == 0:
        eth_may['Coins'][i] = 0
        eth_may['Collateral'][i] = 0
        eth_may['LTV'][i]  = 0
        eth_may['H'][i]    = 0
        eth_may['Debt'][i] = 0
        
    eth_may['Liquidations'][i] = L

# %%
eth_may
# Out:
#           Date         Open         High          Low        Close  \
# t
# 0   2021-05-01  2772.838379  2951.440918  2755.908447  2945.892822
# 1   2021-05-02  2945.560059  2984.891846  2860.526123  2952.056152
# 2   2021-05-03  2951.175781  3450.037842  2951.175781  3431.086182
# 3   2021-05-04  3431.131592  3523.585938  3180.742676  3253.629395
# 4   2021-05-05  3240.554688  3541.462646  3213.101563  3522.783203
# 5   2021-05-06  3524.930908  3598.895996  3386.239990  3490.880371
# 6   2021-05-07  3490.105225  3573.290039  3370.261963  3484.729004
# 7   2021-05-08  3481.988037  3950.165039  3453.768555  3902.647705
# 8   2021-05-09  3911.463135  3981.259033  3743.989014  3928.844727
# 9   2021-05-10  3924.413330  4197.473145  3684.451660  3952.293945
# 10  2021-05-11  3948.271973  4178.208984  3783.889404  4168.701172
# 11  2021-05-12  4174.635742  4362.350586  3785.848633  3785.848633
# 12  2021-05-13  3828.918457  4032.563477  3549.407227  3715.148438
# ...

# %%
liqu = np.round(liqu, decimals=2)
liqu = liqu[['Date', 'Close', 'LTV', 'H', 'Coins', 'Collateral', 'Debt','Liquidations']]
liqu[['Close', 'LTV', 'H', 'Coins', 'Collateral', 'Debt']] = liqu[['Close', 'LTV', 'H', 'Coins', 'Collateral', 'Debt']].astype(float).round(2)
liqu
# Out:
#                   Date    Close   LTV        H  Coins  Collateral     Debt  \
# t
# 0           2021-05-01  2945.89  0.68  2352.94   3.00     8837.68  6000.00
# $\tau_1^-$  2021-05-22  2295.71  0.88  2366.51   3.00     6887.12  6034.60
# $\tau_1^+$  2021-05-22  2295.71  0.81  2195.95   1.62     3711.01  3017.30
# $\tau_2^-$  2021-05-23  2109.58  0.88  2195.95   1.62     3410.14  3017.30
# $\tau_2^+$  2021-05-23  2109.58  0.83  2054.92   0.86     1822.09  1508.65
# $\tau_3^-$  2021-06-21  1888.45  0.93  2070.74   0.86     1631.09  1520.26
# $\tau_3^+$  2021-06-21  1888.45  0.91  2032.34   0.44      830.96   760.13
# $\tau_4^-$  2021-06-21  1888.45  0.91  2032.34   0.44      830.96   760.13
# $\tau_4^+$  2021-06-21  1888.45  0.90  1994.65   0.22      423.33   380.06
# $\tau_5^-$  2021-06-21  1888.45  0.90  1994.65   0.22      423.33   380.06
# $\tau_5^+$  2021-06-21  1888.45  0.88  1957.66   0.11      215.66   190.03
# ...

# %%
# reduced table 
dates = list(set(liqu['Date']))
liqu1 = eth_may.groupby('Liquidations').first()
liqu1.drop(['Open','High','Low','Adj Close','Volume'], axis=1, inplace=True)
print('\n Dates of liquidations:\n', dates)
liqu1
# Out:
#  Dates of liquidations:
#  ['2021-05-23', '2021-05-01', '2021-06-21', '2021-06-22', '2021-05-22']
#                     Date        Close       LTV            H     Coins  \
# Liquidations
# 0             2021-05-01  2945.892822  0.678911  2352.941176  3.000000
# 1             2021-05-23  2109.579834  0.884802  2195.952617  1.616502
# 2             2021-05-24  2643.591064  0.660724  2054.923544  0.863721
# 7             2021-06-22  1874.950073  0.854882  1885.719997  0.029640
# 8             2021-06-23  1989.736328  0.732250  1714.098166  0.016304
#
#                Collateral         Debt
# Liquidations
# 0             8837.678466  6000.000000
# 1             3410.140714  3017.298140
# 2             2283.325941  1508.649070
# 7               55.572652    47.508087
# 8               32.439822    23.754044

# %%
plt.plot(eth_may['Date'], eth_may['Coins'])
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(14))
plt.margins(0,0.05)

xlabel('Date')
ylabel('Number of coins')

plt.savefig('plots/coins_multiple.png', transparent=True)
show()
print('Development of the number of coins in a loan that suffered from', eth_may['Liquidations'].iloc[-1], 'liquidations in total')
# Out:
# Development of the number of coins in a loan that suffered from 8 liquidations in total

# %%
# threshold development in unit of USD price
plt.plot(eth_may['Date'], eth_may['Close'], label='Price')
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(14))
plt.plot(eth_may['H'], label='Price Threshold', color='r')
#plt.legend()
xlabel('Date')
plt.margins(0,0.05)
plt.savefig('plots/pricethreshold_mayjune.png', transparent=True)
show()

# %%
# threshold development in unit of USD price and dates of liquidation events
plt.plot(eth_may['Date'], eth_may['Collateral'], label='Collateral Value')
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(14))
plt.plot(eth_may['H']*eth_may['Coins'], label='Collateral Threshold', color='r')
for i in range(len(dates)):
    plt.axvline(x=dates[i], color='r', linestyle=':', label='Liquidations' if i ==0 else None)
#plt.legend(loc=1)
xlabel('Date')
plt.margins(0,0.05)
plt.savefig('plots/colthreshold_multiple.png', transparent=True)
show()

# %%
# threshold development in unit of collateral USD price
plt.plot(eth_may['Date'], eth_may['Collateral'], label='Collateral Value')
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(14))
plt.plot(eth_may['H']*eth_may['Coins'], label='Collateral Threshold', color='r')
#plt.legend()
xlabel('Date')
plt.margins(0,0.05)
plt.savefig('plots/colthreshold_mayjune.png', transparent=True)
show()

# %%
# threshold development in unit of collateral USD price and liquidation events
plt.plot(eth_may['Date'], eth_may['Close'], label='Price')
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(14))
plt.plot(eth_may['H'], label='Price Threshold', color='r')
for i in range(len(dates)):
    plt.axvline(x=dates[i], color='r', linestyle=':', label='Liquidations' if i ==0 else None)
#plt.legend(loc=1)
xlabel('Date')
plt.margins(0,0.05)
plt.savefig('plots/pricethreshold_multiple.png', transparent=True)
show()

# %%
plt.plot(eth_may['Date'], eth_may['Collateral'], label='Collateral Value')
plt.gca().xaxis.set_major_locator(plt.MultipleLocator(14))
plt.plot(eth_may['H']*eth_may['Coins'], label='Collateral Threshold', color='r')
plt.plot(eth_may['Debt'], label='Debt', color='darkgreen')
#plt.legend()
xlabel('Date')
plt.margins(0,0.05)
plt.savefig('plots/colthresholdprice.png', transparent=True)
show()
